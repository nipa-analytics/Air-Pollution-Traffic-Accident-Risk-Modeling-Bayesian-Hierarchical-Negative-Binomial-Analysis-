# %%
import pandas as pd
import numpy as np

# Load crash data
crash_path = "data_raw/nyc_crashes_2015_2023.csv"
crashes = pd.read_csv(crash_path, low_memory=False)

crashes.head()
# Out:
#   CRASH DATE CRASH TIME   BOROUGH  ZIP CODE  LATITUDE  LONGITUDE  \
# 0  9/11/2021       2:39       NaN       NaN       NaN        NaN
# 1  3/26/2022      11:45       NaN       NaN       NaN        NaN
# 2  11/1/2023       1:29  BROOKLYN   11230.0  40.62179 -73.970024
# 3  6/29/2022       6:55       NaN       NaN       NaN        NaN
# 4  9/21/2022      13:21       NaN       NaN       NaN        NaN
#
#                      LOCATION           ON STREET NAME CROSS STREET NAME  \
# 0                         NaN    WHITESTONE EXPRESSWAY         20 AVENUE
# 1                         NaN  QUEENSBORO BRIDGE UPPER               NaN
# 2      (40.62179, -73.970024)            OCEAN PARKWAY          AVENUE K
# 3                         NaN       THROGS NECK BRIDGE               NaN
# 4                         NaN          BROOKLYN BRIDGE               NaN
#
#   OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 2  \
# 0             NaN  ...                    Unspecified
# 1             NaN  ...                            NaN
# 2             NaN  ...                    Unspecified
# 3             NaN  ...                    Unspecified
# 4             NaN  ...                    Unspecified
#
#    CONTRIBUTING FACTOR VEHICLE 3  CONTRIBUTING FACTOR VEHICLE 4  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                    Unspecified                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
#
#    CONTRIBUTING FACTOR VEHICLE 5  COLLISION_ID  \
# 0                            NaN       4455765
# 1                            NaN       4513547
# 2                            NaN       4675373
# 3                            NaN       4541903
# 4                            NaN       4566131
#
#                    VEHICLE TYPE CODE 1  VEHICLE TYPE CODE 2  \
# 0                                Sedan                Sedan
# 1                                Sedan                  NaN
# 2                                Moped                Sedan
# 3                                Sedan        Pick-up Truck
# 4  Station Wagon/Sport Utility Vehicle                  NaN
#
#    VEHICLE TYPE CODE 3 VEHICLE TYPE CODE 4 VEHICLE TYPE CODE 5
# 0                  NaN                 NaN                 NaN
# 1                  NaN                 NaN                 NaN
# 2                Sedan                 NaN                 NaN
# 3                  NaN                 NaN                 NaN
# 4                  NaN                 NaN                 NaN
#
# [5 rows x 29 columns]

# %% [markdown]
# # Data Cleaning (Crash Data)

# %%
# Convert date column
crashes['CRASH DATE'] = pd.to_datetime(crashes['CRASH DATE'])

# Keep only necessary columns
crashes = crashes[['CRASH DATE', 'BOROUGH']]

# Drop missing boroughs
crashes = crashes.dropna(subset=['BOROUGH'])

crashes.head()
# Out:
#    CRASH DATE   BOROUGH
# 2  2023-11-01  BROOKLYN
# 9  2021-09-11  BROOKLYN
# 10 2021-12-14  BROOKLYN
# 13 2021-12-14     BRONX
# 14 2021-12-14  BROOKLYN

# %% [markdown]
# # Aggregate to Daily Borough Counts
#  This converts millions of rows → ~15k rows.

# %%
daily_accidents = (
    crashes
    .groupby(['CRASH DATE', 'BOROUGH'])
    .size()
    .reset_index(name='accident_count')
)

daily_accidents.head()
# Out:
#   CRASH DATE   BOROUGH  accident_count
# 0 2012-07-27  BROOKLYN               1
# 1 2012-08-01  BROOKLYN               1
# 2 2012-09-25    QUEENS               1
# 3 2013-05-17  BROOKLYN               1
# 4 2013-05-20    QUEENS               1

# %%
daily_accidents.shape
# Out:
# (13359, 3)

# %% [markdown]
# # Load PM2.5 Dataset

# %%
import os
print(os.listdir("data_raw"))
# Out:
# ['.ipynb_checkpoints', 'nyc_crashes_2015_2023.csv']

# %%
import os
os.path.isdir("data_raw/pm25_ny_2015_2023.csv")
# Out:
# False

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\nipas\\bayesian-traffic-airpollution'

# %%
os.getcwd()
# Out:
# 'C:\\Users\\nipas\\bayesian-traffic-airpollution'

# %%
import pandas as pd
import glob
import os

# 1. Identify the pattern of your files
# This looks for all CSV files starting with 'pm25_ny_' in the current directory
file_pattern = 'pm25_ny_*.csv'
all_files = glob.glob(file_pattern)

# Sort the files to ensure they are loaded in chronological order
all_files.sort()

print(f"Found {len(all_files)} files: {all_files}")

# 2. Read each file into a list of DataFrames
df_list = []
for filename in all_files:
    df = pd.read_csv(filename)
    # Optional: add a column to track which year the data came from
    # df['Source_File'] = filename 
    df_list.append(df)

# 3. Concatenate all DataFrames into one
combined_df = pd.concat(df_list, ignore_index=True)

# 4. View the result
print("Successfully merged datasets.")
print(f"Total rows: {len(combined_df)}")
display(combined_df.head())
# Out:
# Found 9 files: ['pm25_ny_2015.csv', 'pm25_ny_2016.csv', 'pm25_ny_2017.csv', 'pm25_ny_2018.csv', 'pm25_ny_2019.csv', 'pm25_ny_2020.csv', 'pm25_ny_2021.csv', 'pm25_ny_2022.csv', 'pm25_ny_2023.csv']
# Successfully merged datasets.
# Total rows: 118454
#          Date Source    Site ID  POC  Daily Mean PM2.5 Concentration  \
# 0  01/03/2015    AQS  360010005    1                             5.2
# 1  01/06/2015    AQS  360010005    1                             7.0
# 2  01/09/2015    AQS  360010005    1                             9.3
# 3  01/12/2015    AQS  360010005    1                            17.1
# 4  01/15/2015    AQS  360010005    1                            23.3
#
#       Units  Daily AQI Value            Local Site Name  Daily Obs Count  \
# 0  ug/m3 LC               29  ALBANY COUNTY HEALTH DEPT                1
# 1  ug/m3 LC               39  ALBANY COUNTY HEALTH DEPT                1
# 2  ug/m3 LC               51  ALBANY COUNTY HEALTH DEPT                1
# 3  ug/m3 LC               66  ALBANY COUNTY HEALTH DEPT                1
# 4  ug/m3 LC               77  ALBANY COUNTY HEALTH DEPT                1
#
#    Percent Complete  ...  Method Code  \
# 0             100.0  ...          118
# 1             100.0  ...          118
# 2             100.0  ...          118
# 3             100.0  ...          118
# 4             100.0  ...          118
#
#                          Method Description  CBSA Code  \
# 0  R & P Model 2025 PM2.5 Sequential w/WINS    10580.0
# 1  R & P Model 2025 PM2.5 Sequential w/WINS    10580.0
# 2  R & P Model 2025 PM2.5 Sequential w/WINS    10580.0
# 3  R & P Model 2025 PM2.5 Sequential w/WINS    10580.0
# 4  R & P Model 2025 PM2.5 Sequential w/WINS    10580.0
#
#                      CBSA Name  State FIPS Code     State  County FIPS Code  \
# 0  Albany-Schenectady-Troy, NY               36  New York                 1
# 1  Albany-Schenectady-Troy, NY               36  New York                 1
# 2  Albany-Schenectady-Troy, NY               36  New York                 1
# 3  Albany-Schenectady-Troy, NY               36  New York                 1
# 4  Albany-Schenectady-Troy, NY               36  New York                 1
#
#    County  Site Latitude Site Longitude
# 0  Albany       42.64225      -73.75464
# 1  Albany       42.64225      -73.75464
# 2  Albany       42.64225      -73.75464
# 3  Albany       42.64225      -73.75464
# 4  Albany       42.64225      -73.75464
#
# [5 rows x 22 columns]

# %% [markdown]
# # Verify loaded data correctly

# %%
combined_df.shape
combined_df.columns
combined_df.head()
# Out:
#          Date Source    Site ID  POC  Daily Mean PM2.5 Concentration  \
# 0  01/03/2015    AQS  360010005    1                             5.2
# 1  01/06/2015    AQS  360010005    1                             7.0
# 2  01/09/2015    AQS  360010005    1                             9.3
# 3  01/12/2015    AQS  360010005    1                            17.1
# 4  01/15/2015    AQS  360010005    1                            23.3
#
#       Units  Daily AQI Value            Local Site Name  Daily Obs Count  \
# 0  ug/m3 LC               29  ALBANY COUNTY HEALTH DEPT                1
# 1  ug/m3 LC               39  ALBANY COUNTY HEALTH DEPT                1
# 2  ug/m3 LC               51  ALBANY COUNTY HEALTH DEPT                1
# 3  ug/m3 LC               66  ALBANY COUNTY HEALTH DEPT                1
# 4  ug/m3 LC               77  ALBANY COUNTY HEALTH DEPT                1
#
#    Percent Complete  ...  Method Code  \
# 0             100.0  ...          118
# 1             100.0  ...          118
# 2             100.0  ...          118
# 3             100.0  ...          118
# 4             100.0  ...          118
#
#                          Method Description  CBSA Code  \
# 0  R & P Model 2025 PM2.5 Sequential w/WINS    10580.0
# 1  R & P Model 2025 PM2.5 Sequential w/WINS    10580.0
# 2  R & P Model 2025 PM2.5 Sequential w/WINS    10580.0
# 3  R & P Model 2025 PM2.5 Sequential w/WINS    10580.0
# 4  R & P Model 2025 PM2.5 Sequential w/WINS    10580.0
#
#                      CBSA Name  State FIPS Code     State  County FIPS Code  \
# 0  Albany-Schenectady-Troy, NY               36  New York                 1
# 1  Albany-Schenectady-Troy, NY               36  New York                 1
# 2  Albany-Schenectady-Troy, NY               36  New York                 1
# 3  Albany-Schenectady-Troy, NY               36  New York                 1
# 4  Albany-Schenectady-Troy, NY               36  New York                 1
#
#    County  Site Latitude Site Longitude
# 0  Albany       42.64225      -73.75464
# 1  Albany       42.64225      -73.75464
# 2  Albany       42.64225      -73.75464
# 3  Albany       42.64225      -73.75464
# 4  Albany       42.64225      -73.75464
#
# [5 rows x 22 columns]

# %% [markdown]
# # check actual coloumn name

# %%
combined_df.columns
# Out:
# Index(['Date', 'Source', 'Site ID', 'POC', 'Daily Mean PM2.5 Concentration',
#        'Units', 'Daily AQI Value', 'Local Site Name', 'Daily Obs Count',
#        'Percent Complete', 'AQS Parameter Code', 'AQS Parameter Description',
#        'Method Code', 'Method Description', 'CBSA Code', 'CBSA Name',
#        'State FIPS Code', 'State', 'County FIPS Code', 'County',
#        'Site Latitude', 'Site Longitude'],
#       dtype='str')

# %% [markdown]
# # Clean coloumn name

# %%
combined_df.columns = combined_df.columns.str.strip()
combined_df.columns = combined_df.columns.str.replace(' ', '_')
combined_df.columns = combined_df.columns.str.lower()

combined_df.columns
# Out:
# Index(['date', 'source', 'site_id', 'poc', 'daily_mean_pm2.5_concentration',
#        'units', 'daily_aqi_value', 'local_site_name', 'daily_obs_count',
#        'percent_complete', 'aqs_parameter_code', 'aqs_parameter_description',
#        'method_code', 'method_description', 'cbsa_code', 'cbsa_name',
#        'state_fips_code', 'state', 'county_fips_code', 'county',
#        'site_latitude', 'site_longitude'],
#       dtype='str')

# %%
pm25 = combined_df[['date', 'county', 'daily_mean_pm2.5_concentration']].copy()
pm25['date'] = pd.to_datetime(pm25['date'])

county_to_borough = {
    'Bronx': 'BRONX',
    'Kings': 'BROOKLYN',
    'New York': 'MANHATTAN',
    'Queens': 'QUEENS',
    'Richmond': 'STATEN ISLAND'
}

pm25['BOROUGH'] = pm25['county'].map(county_to_borough)
pm25 = pm25.dropna(subset=['BOROUGH'])

# %% [markdown]
# # Map County → NYC Borough

# %%
county_to_borough = {
    'Bronx': 'BRONX',
    'Kings': 'BROOKLYN',
    'New York': 'MANHATTAN',
    'Queens': 'QUEENS',
    'Richmond': 'STATEN ISLAND'
}

pm25['BOROUGH'] = pm25['county'].map(county_to_borough)

pm25 = pm25.dropna(subset=['BOROUGH'])

# %%
pm25['BOROUGH'].unique()
# Out:
# <StringArray>
# ['BRONX', 'BROOKLYN', 'MANHATTAN', 'QUEENS', 'STATEN ISLAND']
# Length: 5, dtype: str

# %% [markdown]
# # Aggregate to Daily Borough Level

# %%
daily_pm25 = (
    pm25
    .groupby(['date', 'BOROUGH'])['daily_mean_pm2.5_concentration']
    .mean()
    .reset_index()
)

daily_pm25.rename(columns={
    'date': 'CRASH DATE',
    'daily_mean_pm2.5_concentration': 'pm25'
}, inplace=True)

# %% [markdown]
# # Merge With Crash Panel

# %%
daily_accidents = (
    crashes
    .groupby(['CRASH DATE', 'BOROUGH'])
    .size()
    .reset_index(name='accident_count')
)

# %%
panel = pd.merge(
    daily_accidents,
    daily_pm25,
    on=['CRASH DATE', 'BOROUGH'],
    how='inner'
)

panel.head()
panel.shape
# Out:
# (12057, 4)

# %% [markdown]
# # Add Time Controls + Lag

# %%
panel = panel.sort_values(['BOROUGH', 'CRASH DATE'])

panel['day_of_week'] = panel['CRASH DATE'].dt.dayofweek
panel['month'] = panel['CRASH DATE'].dt.month

panel['pm25_lag1'] = (
    panel.groupby('BOROUGH')['pm25'].shift(1)
)

panel = panel.dropna()

# %% [markdown]
# # Bayesian Hierarchical Negative Binomial Model

# %% [markdown]
# # Each accident count y_i follows a Negative Binomial distribution
#
# y_i ~ NegativeBinomial(μ_i, φ)
#
# # Log link function:
# log(μ_i) = α_borough[i] + β * PM25_i
#
# # Borough-level hierarchical intercept:
# α_b ~ Normal(μ_α, σ_α)
#
# # Hyperpriors:
# μ_α ~ Normal(4, 1)
# σ_α ~ HalfNormal(2)
#
# # PM2.5 effect prior:
# β ~ Normal(0, 1)
#
# # Overdispersion prior:
# φ ~ HalfNormal(5)
#
# # Variance structure of Negative Binomial:
# Var(y_i) = μ_i + μ_i^2 / φ
#
# # This model estimates the posterior:
# p(α, β, φ | y)
#
# # using MCMC sampling (e.g., NUTS),
# # which draws samples directly from the true posterior

# %% [markdown]
# Borough intercepts are hierarchical (partial pooling)
#
# Pollution effect is global

# %% [markdown]
# # Encode Borough as Numeric

# %%
import numpy as np

panel['borough_code'] = panel['BOROUGH'].astype('category').cat.codes

n_boroughs = panel['borough_code'].nunique()

# %% [markdown]
# # Standardize Pollution (Very Important for Bayesian Models)

# %%
panel['pm25_lag1_std'] = (
    panel['pm25_lag1'] - panel['pm25_lag1'].mean()
) / panel['pm25_lag1'].std()

# %% [markdown]
# # Build Bayesian Hierarchical Poisson Model (PyMC)
#
# Make sure PyMC is installed:

# %%
pip install pymc arviz
# Out:
# Requirement already satisfied: pymc in C:\Users\nipas\anaconda3\envs\bayes_traffic\Lib\site-packages (5.28.0)
# Requirement already satisfied: arviz in C:\Users\nipas\anaconda3\envs\bayes_traffic\Lib\site-packages (0.23.4)
# Requirement already satisfied: cachetools<7,>=4.2.1 in C:\Users\nipas\anaconda3\envs\bayes_traffic\Lib\site-packages (from pymc) (6.2.6)
# Requirement already satisfied: cloudpickle in C:\Users\nipas\anaconda3\envs\bayes_traffic\Lib\site-packages (from pymc) (3.1.2)
# Requirement already satisfied: numpy>=1.25.0 in C:\Users\nipas\anaconda3\envs\bayes_traffic\Lib\site-packages (from pymc) (2.4.2)
# Requirement already satisfied: pandas>=0.24.0 in C:\Users\nipas\anaconda3\envs\bayes_traffic\Lib\site-packages (from pymc) (3.0.0)
# Requirement already satisfied: pytensor<2.39,>=2.38.0 in C:\Users\nipas\anaconda3\envs\bayes_traffic\Lib\site-packages (from pymc) (2.38.0)
# Requirement already satisfied: rich>=13.7.1 in C:\Users\nipas\anaconda3\envs\bayes_traffic\Lib\site-packages (from pymc) (14.3.3)
# Requirement already satisfied: scipy>=1.4.1 in C:\Users\nipas\anaconda3\envs\bayes_traffic\Lib\site-packages (from pymc) (1.17.0)
# Requirement already satisfied: threadpoolctl<4.0.0,>=3.1.0 in C:\Users\nipas\anaconda3\envs\bayes_traffic\Lib\site-packages (from pymc) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in C:\Users\nipas\anaconda3\envs\bayes_traffic\Lib\site-packages (from pymc) (4.15.0)
# Requirement already satisfied: setuptools>=59.0.0 in C:\Users\nipas\anaconda3\envs\bayes_traffic\Lib\site-packages (from pytensor<2.39,>=2.38.0->pymc) (80.10.2)
# Requirement already satisfied: numba<1,>0.57 in C:\Users\nipas\anaconda3\envs\bayes_traffic\Lib\site-packages (from pytensor<2.39,>=2.38.0->pymc) (0.64.0)
# Requirement already satisfied: filelock>=3.15 in C:\Users\nipas\anaconda3\envs\bayes_traffic\Lib\site-packages (from pytensor<2.39,>=2.38.0->pymc) (3.24.3)
# Requirement already satisfied: etuples in C:\Users\nipas\anaconda3\envs\bayes_traffic\Lib\site-packages (from pytensor<2.39,>=2.38.0->pymc) (0.3.10)
# Requirement already satisfied: logical-unification in C:\Users\nipas\anaconda3\envs\bayes_traffic\Lib\site-packages (from pytensor<2.39,>=2.38.0->pymc) (0.4.7)
# Requirement already satisfied: miniKanren in C:\Users\nipas\anaconda3\envs\bayes_traffic\Lib\site-packages (from pytensor<2.39,>=2.38.0->pymc) (1.0.5)
# Requirement already satisfied: cons in C:\Users\nipas\anaconda3\envs\bayes_traffic\Lib\site-packages (from pytensor<2.39,>=2.38.0->pymc) (0.4.7)
# Requirement already satisfied: llvmlite<0.47,>=0.46.0dev0 in C:\Users\nipas\anaconda3\envs\bayes_traffic\Lib\site-packages (from numba<1,>0.57->pytensor<2.39,>=2.38.0->pymc) (0.46.0)
# Requirement already satisfied: matplotlib>=3.8 in C:\Users\nipas\anaconda3\envs\bayes_traffic\Lib\site-packages (from arviz) (3.10.8)
# Requirement already satisfied: packaging in C:\Users\nipas\anaconda3\envs\bayes_traffic\Lib\site-packages (from arviz) (25.0)
# Requirement already satisfied: xarray>=2023.7.0 in C:\Users\nipas\anaconda3\envs\bayes_traffic\Lib\site-packages (from arviz) (2026.2.0)
# Requirement already satisfied: h5netcdf>=1.0.2 in C:\Users\nipas\anaconda3\envs\bayes_traffic\Lib\site-packages (from arviz) (1.8.1)
# Requirement already satisfied: h5py in C:\Users\nipas\anaconda3\envs\bayes_traffic\Lib\site-packages (from arviz) (3.15.1)
# Requirement already satisfied: xarray-einstats>=0.3 in C:\Users\nipas\anaconda3\envs\bayes_traffic\Lib\site-packages (from arviz) (0.9.1)
# Requirement already satisfied: platformdirs in C:\Users\nipas\anaconda3\envs\bayes_traffic\Lib\site-packages (from arviz) (4.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\nipas\anaconda3\envs\bayes_traffic\Lib\site-packages (from matplotlib>=3.8->arviz) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\nipas\anaconda3\envs\bayes_traffic\Lib\site-packages (from matplotlib>=3.8->arviz) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\nipas\anaconda3\envs\bayes_traffic\Lib\site-packages (from matplotlib>=3.8->arviz) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\nipas\anaconda3\envs\bayes_traffic\Lib\site-packages (from matplotlib>=3.8->arviz) (1.4.9)
# Requirement already satisfied: pillow>=8 in C:\Users\nipas\anaconda3\envs\bayes_traffic\Lib\site-packages (from matplotlib>=3.8->arviz) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in C:\Users\nipas\anaconda3\envs\bayes_traffic\Lib\site-packages (from matplotlib>=3.8->arviz) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\nipas\anaconda3\envs\bayes_traffic\Lib\site-packages (from matplotlib>=3.8->arviz) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\nipas\anaconda3\envs\bayes_traffic\Lib\site-packages (from pandas>=0.24.0->pymc) (2025.3)
# Requirement already satisfied: six>=1.5 in C:\Users\nipas\anaconda3\envs\bayes_traffic\Lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.8->arviz) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\nipas\anaconda3\envs\bayes_traffic\Lib\site-packages (from rich>=13.7.1->pymc) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\nipas\anaconda3\envs\bayes_traffic\Lib\site-packages (from rich>=13.7.1->pymc) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\nipas\anaconda3\envs\bayes_traffic\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.7.1->pymc) (0.1.2)
# Requirement already satisfied: toolz in C:\Users\nipas\anaconda3\envs\bayes_traffic\Lib\site-packages (from logical-unification->pytensor<2.39,>=2.38.0->pymc) (1.1.0)
# Requirement already satisfied: multipledispatch in C:\Users\nipas\anaconda3\envs\bayes_traffic\Lib\site-packages (from logical-unification->pytensor<2.39,>=2.38.0->pymc) (1.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Check Your NumPy Version

# %%
import numpy as np
np.__version__
# Out:
# '2.4.2'

# %% [markdown]
# # Model

# %%
panel_sample = panel.sample(n=5000, random_state=42)

# %%
import pymc as pm
import arviz as az
import numpy as np

coords = {"borough": panel['BOROUGH'].unique()}

with pm.Model(coords=coords) as model:

    # Data
    borough_idx = pm.Data("borough_idx", panel['borough_code'].values)
    pm25_std = pm.Data("pm25_std", panel['pm25_lag1_std'].values)
    accidents = panel['accident_count'].values

    # Hierarchical intercept (correct scale)
    mu_alpha = pm.Normal("mu_alpha", mu=4, sigma=1)
    sigma_alpha = pm.HalfNormal("sigma_alpha", sigma=2)

    alpha = pm.Normal("alpha", mu=mu_alpha, sigma=sigma_alpha, dims="borough")

    # PM2.5 effect
    beta_pm25 = pm.Normal("beta_pm25", mu=0, sigma=1)

    # Linear predictor
    log_lambda = alpha[borough_idx] + beta_pm25 * pm25_std
    lambda_ = pm.math.exp(log_lambda)

    # Overdispersion
    phi = pm.HalfNormal("phi", sigma=5)

    y_obs = pm.NegativeBinomial(
        "y_obs",
        mu=lambda_,
        alpha=phi,
        observed=accidents
    )

    # MCMC
    trace = pm.sample(
        draws=700,
        tune=700,
        chains=4,          # faster
        cores=4,
        target_accept=0.9,
        progressbar=True
    )
# Out:
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [mu_alpha, sigma_alpha, alpha, beta_pm25, phi]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 700 tune and 700 draw iterations (2_800 + 2_800 draws total) took 178 seconds.

# %%
az.summary(trace, var_names=["beta_pm25", "mu_alpha", "sigma_alpha"])
# Out:
#               mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# beta_pm25   -0.007  0.004  -0.014    0.003      0.000    0.000    4542.0
# mu_alpha     3.822  0.447   2.948    4.679      0.008    0.010    3587.0
# sigma_alpha  1.116  0.451   0.474    1.927      0.009    0.015    3833.0
#
#              ess_tail  r_hat
# beta_pm25      2006.0    1.0
# mu_alpha       2037.0    1.0
# sigma_alpha    2032.0    1.0

# %%
np.exp(trace.posterior['beta_pm25'].mean().values)
# Out:
# np.float64(0.9932953800921821)

# %% [markdown]
# # Posterior Predictive Check

# %%
with model:
    idata_ppc = pm.sample_posterior_predictive(trace, extend_inferencedata=True)

az.plot_ppc(idata_ppc)
# Out:
# Sampling: [y_obs]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Axes: xlabel='y_obs'>

# %%
panel['accident_count'].describe()
# Out:
# count    12052.000000
# mean        53.440591
# std         37.557255
# min          1.000000
# 25%         25.000000
# 50%         47.000000
# 75%         74.000000
# max        214.000000
# Name: accident_count, dtype: float64

# %%
panel['pm25_lag1_std'].describe()
# Out:
# count    1.205200e+04
# mean     1.297041e-16
# std      1.000000e+00
# min     -1.642831e+00
# 25%     -5.289428e-01
# 50%     -1.672328e-01
# 75%      3.165384e-01
# max      2.980549e+01
# Name: pm25_lag1_std, dtype: float64

# %% [markdown]
# # Conclusion

# %% [markdown]
# A hierarchical Bayesian Negative Binomial model was estimated using four-chain MCMC to assess the relationship between PM2.5 exposure and traffic accident counts. Convergence diagnostics indicated excellent mixing (R-hat ≈ 1.00), and posterior predictive checks demonstrated strong calibration.
#
# Results indicate substantial borough-level heterogeneity in accident rates. However, there is no statistically credible evidence that short-term PM2.5 exposure has a meaningful impact on accident frequency after accounting for geographic variation and overdispersion.
#
# Overall, accident variability appears to be driven more strongly by spatial factors than by PM2.5 fluctuations in this dataset.
